# %%
import pandas as pd

# %%
lwi = pd.read_csv("data/final_locations.csv")

# %%
lwi
# Out:
#       Unnamed: 0   app_id                               title  \
# 0              0       10                      Counter-Strike
# 1              1       20               Team Fortress Classic
# 2              2       30                       Day of Defeat
# 3              3       40                  Deathmatch Classic
# 4              4       50           Half-Life: Opposing Force
# ...          ...      ...                                 ...
# 7284        7379  3144190                          Break Wolf
# 7285        7380  3146520                          WEBFISHING
# 7286        7381  3147430            Journey to Incrementalia
# 7287        7382  3149370            ROGUE LIGHT DECK BUILDER
# 7288        7386  3152540  Hydroponics Farm & Store Simulator
#
#                     image_path    w    h             x             y
# 0          steam_images/10.jpg  616  353 -30686.416896  26781.749076
# 1          steam_images/20.jpg  231   87 -17310.191360  34479.140080
# ...
